# %%
# the code below should represent what the package is supposed to be able to do
# so pip install msd_detection

# from msd_detection import detect_defect

#detect_defect(image) -> output : image with defects as numpy array

# %%
import matplotlib.pyplot as plt 
from ultralytics import YOLO

def detect_defects(image,model = YOLO('./project1/exp16/weights/best.pt')):
    res = model(image)
    res_plotted = res[0].plot()
    plt.imshow(res_plotted)
    plt.axis('off')
    plt.show()
    
    #cv2.imshow("result", res_plotted)
image =  './yolo_dataset/val/images/img_01_424995500_00289.jpg'
detect_defects(image)
# Out:
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# image 1/1 /home/vboxuser/Desktop/Metal-Surface-Defect-Detection/yolo_dataset/val/images/img_01_424995500_00289.jpg: 640x640 1 water_spot, 4869.9ms
# Speed: 208.3ms preprocess, 4869.9ms inference, 170.8ms postprocess per image at shape (1, 3, 640, 640)
